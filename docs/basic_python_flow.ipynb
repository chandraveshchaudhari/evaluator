# %% [markdown]
# # Basic Python Flow

# %%
import sys
from pathlib import Path

# current notebook is inside ./docs/
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent     # go up to project root

sys.path.append(str(PROJECT_ROOT / "src"))

from evaluator import Evaluator

# %%
eval = Evaluator("/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/solution/python/sample_solutions.ipynb", "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/submissions/python")
eval.run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 eval = Evaluator("/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/solution/python/sample_solutions.ipynb", "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/submissions/python")
# ----> 2 eval.run()
#
# File /Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/evaluator.py:54, in Evaluator.run(self)
#      49 """Run the full pipeline: load -> execute -> compare -> report.
#      50
#      51 Returns the generated report object from the reporting service.
#      52 """
#      53 submissions = self.load()
# ---> 54 executed = self.execute_all(submissions)
#      55 report = self.build_report(executed)
#      56 return report
#
# File /Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/evaluator.py:70, in Evaluator.execute_all(self, submissions)
#      64 def execute_all(self, submissions: Iterable[Path]) -> List[Any]:
#      65     """Execute all submissions against the instructor solution.
#      66
#      67     Returns a list of executed objects (the execution service is free to
#      68     return domain-specific result objects).
#      69     """
# ---> 70     solution_file = submissions.load_solution()
#      71     executed_results: List[Any] = []
#      72     for sub in submissions.list_submissions():
#
# TypeError: IngestionService.load_solution() missing 1 required positional argument: 'solution_path'

# %% [markdown]
# # EOF
