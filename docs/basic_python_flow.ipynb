# %% [markdown]
# # Basic Python Flow

# %%
import sys
from pathlib import Path

# current notebook is inside ./docs/
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent     # go up to project root

sys.path.append(str(PROJECT_ROOT / "src"))

from evaluator import Evaluator

# %%
eval = Evaluator("/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/solution/python/sample_solutions.ipynb", "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/submissions/python")
result = eval.run()
# Out:
# /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)

# %%
result.to_html("/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/reports/python/report.html")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result.to_html("/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/reports/python/report.html")
#
# File /Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/reporting/reporting_service.py:115, in ReportingService.to_html(self, path)
#     113 for (file, student, roll) in grouped.groups.keys():
#     114     opt_id = f"{student}_{roll}".replace(" ", "_")
# --> 115     html_out.write(f'<option value="{opt_id}">{html.escape(student)} ({html.escape(str(roll))})</option>')
#     117 html_out.write("</select><hr>")
#     119 # Grouped content
#
# UnboundLocalError: cannot access local variable 'html' where it is not associated with a value

# %%
result.to_html()
# Out:
# [{'student_path': PosixPath('/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/submissions/python/student_assignment_partial_incorrect.ipynb'),
#   'execution': {'namespace': {'name': 'student name partial',
#     'roll_number': 'student roll number partial',
#     'question_one': <function question_one(nums: list[int]) -> int>,
#     'question_two': <function question_two(xs: list) -> list>,
#     'question_three': <function question_three(xs: list) -> dict>,
#     'question_four': <function question_four(nested: list[list]) -> list>,
#     'question_five': <function question_five(d: dict) -> dict>,
#     '__builtins__': {'__name__': 'builtins',
#      '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.",
#      '__package__': '',
#      '__loader__': _frozen_importlib.BuiltinImporter,
#      '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#      '__build_class__': <function __build_class__>,
#      '__import__': <function __import__(name, globals=None, locals=None, fromlist=(), level=0)>,
#      'abs': <function abs(x, /)>,
#      'all': <function all(iterable, /)>,
#      'any': <function any(iterable, /)>,
#      'ascii': <function ascii(obj, /)>,
#      'bin': <function bin(number, /)>,
#      'breakpoint': <function breakpoint(*args, **kws)>,
#      'callable': <function callable(obj, /)>,
#      'chr': <function chr(i, /)>,
#      'compile': <function compile(source, filename, mode, flags=0, dont_inherit=False, optimize=-1, *, _feature_version=-1)>,
#      'delattr': <function delattr(obj, name, /)>,
#      'dir': <function dir>,
#      'divmod': <function divmod(x, y, /)>,
#      'eval': <function eval(source, /, globals=None, locals=None)>,
#      'exec': <function exec(source, /, globals=None, locals=None, *, closure=None)>,
#      'format': <function format(value, format_spec='', /)>,
#      'getattr': <function getattr>,
#      'globals': <function globals()>,
#      'hasattr': <function hasattr(obj, name, /)>,
#      'hash': <function hash(obj, /)>,
#      'hex': <function hex(number, /)>,
#      'id': <function id(obj, /)>,
#      'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x1082af4d0>>,
#      'isinstance': <function isinstance(obj, class_or_tuple, /)>,
#      'issubclass': <function issubclass(cls, class_or_tuple, /)>,
#      'iter': <function iter>,
#      'aiter': <function aiter(async_iterable, /)>,
#      'len': <function len(obj, /)>,
#      'locals': <function locals()>,
#      'max': <function max>,
#      'min': <function min>,
#      'next': <function next>,
#      'anext': <function anext>,
#      'oct': <function oct(number, /)>,
#      'ord': <function ord(character, /)>,
#      'pow': <function pow(base, exp, mod=None)>,
#      'print': <function print(*args, sep=' ', end='\n', file=None, flush=False)>,
#      'repr': <function repr(obj, /)>,
#      'round': <function round(number, ndigits=None)>,
#      'setattr': <function setattr(obj, name, value, /)>,
#      'sorted': <function sorted(iterable, /, *, key=None, reverse=False)>,
#      'sum': <function sum(iterable, /, start=0)>,
#      'vars': <function vars>,
#      'None': None,
#      'Ellipsis': Ellipsis,
#      'NotImplemented': NotImplemented,
#      'False': False,
#      'True': True,
#      'bool': bool,
#      'memoryview': memoryview,
#      'bytearray': bytearray,
#      'bytes': bytes,
#      'classmethod': classmethod,
#      'complex': complex,
#      'dict': dict,
#      'enumerate': enumerate,
#      'filter': filter,
#      'float': float,
#      'frozenset': frozenset,
#      'property': property,
#      'int': int,
#      'list': list,
#      'map': map,
#      'object': object,
#      'range': range,
#      'reversed': reversed,
#      'set': set,
#      'slice': slice,
#      'staticmethod': staticmethod,
#      'str': str,
#      'super': super,
#      'tuple': tuple,
#      'type': type,
#      'zip': zip,
#      '__debug__': True,
#      'BaseException': BaseException,
#      'BaseExceptionGroup': BaseExceptionGroup,
#      'Exception': Exception,
#      'GeneratorExit': GeneratorExit,
#      'KeyboardInterrupt': KeyboardInterrupt,
#      'SystemExit': SystemExit,
#      'ArithmeticError': ArithmeticError,
#      'AssertionError': AssertionError,
#      'AttributeError': AttributeError,
#      'BufferError': BufferError,
#      'EOFError': EOFError,
#      'ImportError': ImportError,
#      'LookupError': LookupError,
#      'MemoryError': MemoryError,
#      'NameError': NameError,
#      'OSError': OSError,
#      'ReferenceError': ReferenceError,
#      'RuntimeError': RuntimeError,
#      'StopAsyncIteration': StopAsyncIteration,
#      'StopIteration': StopIteration,
#      'SyntaxError': SyntaxError,
#      'SystemError': SystemError,
#      'TypeError': TypeError,
#      'ValueError': ValueError,
#      'Warning': Warning,
#      'FloatingPointError': FloatingPointError,
#      'OverflowError': OverflowError,
#      'ZeroDivisionError': ZeroDivisionError,
#      'BytesWarning': BytesWarning,
#      'DeprecationWarning': DeprecationWarning,
#      'EncodingWarning': EncodingWarning,
#      'FutureWarning': FutureWarning,
#      'ImportWarning': ImportWarning,
#      'PendingDeprecationWarning': PendingDeprecationWarning,
#      'ResourceWarning': ResourceWarning,
#      'RuntimeWarning': RuntimeWarning,
#      'SyntaxWarning': SyntaxWarning,
#      'UnicodeWarning': UnicodeWarning,
#      'UserWarning': UserWarning,
#      'BlockingIOError': BlockingIOError,
#      'ChildProcessError': ChildProcessError,
#      'ConnectionError': ConnectionError,
#      'FileExistsError': FileExistsError,
#      'FileNotFoundError': FileNotFoundError,
#      'InterruptedError': InterruptedError,
#      'IsADirectoryError': IsADirectoryError,
#      'NotADirectoryError': NotADirectoryError,
#      'PermissionError': PermissionError,
#      'ProcessLookupError': ProcessLookupError,
#      'TimeoutError': TimeoutError,
#      'IndentationError': IndentationError,
#      '_IncompleteInputError': _IncompleteInputError,
#      'IndexError': IndexError,
#      'KeyError': KeyError,
#      'ModuleNotFoundError': ModuleNotFoundError,
#      'NotImplementedError': NotImplementedError,
#      'PythonFinalizationError': PythonFinalizationError,
#      'RecursionError': RecursionError,
#      'UnboundLocalError': UnboundLocalError,
#      'UnicodeError': UnicodeError,
#      'BrokenPipeError': BrokenPipeError,
#      'ConnectionAbortedError': ConnectionAbortedError,
#      'ConnectionRefusedError': ConnectionRefusedError,
#      'ConnectionResetError': ConnectionResetError,
#      'TabError': TabError,
#      'UnicodeDecodeError': UnicodeDecodeError,
#      'UnicodeEncodeError': UnicodeEncodeError,
#      'UnicodeTranslateError': UnicodeTranslateError,
#      'ExceptionGroup': ExceptionGroup,
#      'EnvironmentError': OSError,
#      'IOError': OSError,
#      'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#      'copyright': Copyright (c) 2001-2024 Python Software Foundation.
#      All Rights Reserved.
#
#      Copyright (c) 2000 BeOpen.com.
#      All Rights Reserved.
#
#      Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#      All Rights Reserved.
#
#      Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#      All Rights Reserved.,
#      'credits':     Thanks to CWI, CNRI, BeOpen, Zope Corporation, the Python Software
#          Foundation, and a cast of thousands for supporting Python
#          development.  See www.python.org for more information.,
#      'license': Type license() to see the full license text,
#      'help': Type help() for interactive help, or help(object) for help about object.,
#      'execfile': <function _pydev_bundle._pydev_execfile.execfile(file, glob=None, loc=None)>,
#      'runfile': <function _pydev_bundle.pydev_umd.runfile(filename, args=None, wdir=None, namespace=None)>,
#      '__IPYTHON__': True,
#      'display': <function IPython.core.display_functions.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, raw=False, clear=False, **kwargs)>,
#      'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x1085fd2b0>>}},
#    'errors': [],
#    'traceback': None,
#    'success': True},
#   'results': [{'question': 'question_one',
#     'assertion': 'assert question_one([1,2,2,3]) == 6',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_one',
#     'assertion': 'assert question_one([]) == 0',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_two',
#     'assertion': 'assert question_two([1,2,3]) == [3,2,1]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_two',
#     'assertion': 'assert question_two([]) == []',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_three',
#     'assertion': 'assert question_three([1,2,2,3]) == {1:1,2:2,3:1}',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_three',
#     'assertion': 'assert question_three([]) == {}',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_four',
#     'assertion': 'assert question_four([[1,2],[3,4]]) == [1,2,3,4]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_four',
#     'assertion': 'assert question_four([]) == []',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_five',
#     'assertion': "assert question_five({'a':1,'b':2,'c':1}) == {1:['a','c'],2:['b']}",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_six',
#     'assertion': "assert question_six({'x':1,'y':2},{'y':3,'z':4}) == {'x':1,'y':5,'z':4}",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nNameError: name \'question_six\' is not defined. Did you mean: \'question_one\'?\n',
#     'score': 0},
#    {'question': 'question_eight',
#     'assertion': 'assert question_eight("hello world") == ["hello","world"]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nNameError: name \'question_eight\' is not defined. Did you mean: \'question_five\'?\n',
#     'score': 0},
#    {'question': 'question_eight',
#     'assertion': 'assert question_eight("") == []',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nNameError: name \'question_eight\' is not defined. Did you mean: \'question_five\'?\n',
#     'score': 0},
#    {'question': 'question_ten',
#     'assertion': 'assert question_ten("I love python") == 6',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nNameError: name \'question_ten\' is not defined. Did you mean: \'question_two\'?\n',
#     'score': 0},
#    {'question': 'question_ten',
#     'assertion': 'assert question_ten("") == 0',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nNameError: name \'question_ten\' is not defined. Did you mean: \'question_two\'?\n',
#     'score': 0},
#    {'question': 'question_eleven',
#     'assertion': 'assert question_eleven([1,2,3],[2,3,4]) == {2,3}',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nNameError: name \'question_eleven\' is not defined. Did you mean: \'question_five\'?\n',
#     'score': 0},
#    {'question': 'question_twelve',
#     'assertion': 'assert question_twelve([1,2,2,3,1]) == [1,2,3]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nNameError: name \'question_twelve\' is not defined. Did you mean: \'question_two\'?\n',
#     'score': 0},
#    {'question': 'question_thirteen',
#     'assertion': 'assert question_thirteen([1,2,3]) == [1,4,9]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nNameError: name \'question_thirteen\' is not defined. Did you mean: \'question_three\'?\n',
#     'score': 0},
#    {'question': 'question_fourteen',
#     'assertion': 'assert question_fourteen([1,2,3,4]) == [2,4]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nNameError: name \'question_fourteen\' is not defined. Did you mean: \'question_four\'?\n',
#     'score': 0}]},
#  {'student_path': PosixPath('/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/submissions/python/sample_solutions.ipynb'),
#   'execution': {'namespace': {'name': 'student name',
#     'roll_number': 'student roll number',
#     'question_one': <function question_one(nums: list[int]) -> int>,
#     'question_two': <function question_two(xs: list) -> list>,
#     'question_three': <function question_three(xs: list) -> dict>,
#     'question_four': <function question_four(nested: list[list]) -> list>,
#     'question_five': <function question_five(d: dict) -> dict>,
#     'question_six': <function question_six(a: dict, b: dict) -> dict>,
#     'question_seven': <function question_seven(nums: list[int], k: int) -> list[int]>,
#     'out':    num
#     0  1.0
#     1  9.0
#     2  3.0,
#     'question_eight': <function question_eight(s: str) -> list[str]>,
#     'question_nine': <function question_nine(words: list[str], sep: str = ' ') -> str>,
#     'question_ten': <function question_ten(sentence: str) -> int>,
#     'question_eleven': <function question_eleven(a: list, b: list) -> set>,
#     'question_twelve': <function question_twelve(xs: list) -> list>,
#     'question_thirteen': <function question_thirteen(nums: list[int]) -> list[int]>,
#     'question_fourteen': <function question_fourteen(nums: list[int]) -> list[int]>,
#     'question_fifteen': <function question_fifteen(values: list) -> 'pd.Series'>,
#     'pd': <module 'pandas' from '/Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages/pandas/__init__.py'>,
#     's': a    2
#     b    1
#     Name: count, dtype: int64,
#     'question_sixteen': <function question_sixteen(df: 'pd.DataFrame') -> 'pd.DataFrame'>,
#     'df':    num
#     0  1.0
#     1  NaN
#     2  3.0,
#     'question_seventeen': <function question_seventeen(a: 'pd.DataFrame', b: 'pd.DataFrame') -> 'pd.DataFrame'>,
#     'a':    x
#     0  1,
#     'b':    x
#     0  2,
#     'question_eighteen': <function question_eighteen(dfs: list) -> 'pd.DataFrame'>,
#     'question_nineteen': <function question_nineteen(df: 'pd.DataFrame') -> 'pd.DataFrame'>,
#     'question_twenty': <function question_twenty(df: 'pd.DataFrame', fill_value=0) -> 'pd.DataFrame'>,
#     '__builtins__': {'__name__': 'builtins',
#      '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.",
#      '__package__': '',
#      '__loader__': _frozen_importlib.BuiltinImporter,
#      '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#      '__build_class__': <function __build_class__>,
#      '__import__': <function __import__(name, globals=None, locals=None, fromlist=(), level=0)>,
#      'abs': <function abs(x, /)>,
#      'all': <function all(iterable, /)>,
#      'any': <function any(iterable, /)>,
#      'ascii': <function ascii(obj, /)>,
#      'bin': <function bin(number, /)>,
#      'breakpoint': <function breakpoint(*args, **kws)>,
#      'callable': <function callable(obj, /)>,
#      'chr': <function chr(i, /)>,
#      'compile': <function compile(source, filename, mode, flags=0, dont_inherit=False, optimize=-1, *, _feature_version=-1)>,
#      'delattr': <function delattr(obj, name, /)>,
#      'dir': <function dir>,
#      'divmod': <function divmod(x, y, /)>,
#      'eval': <function eval(source, /, globals=None, locals=None)>,
#      'exec': <function exec(source, /, globals=None, locals=None, *, closure=None)>,
#      'format': <function format(value, format_spec='', /)>,
#      'getattr': <function getattr>,
#      'globals': <function globals()>,
#      'hasattr': <function hasattr(obj, name, /)>,
#      'hash': <function hash(obj, /)>,
#      'hex': <function hex(number, /)>,
#      'id': <function id(obj, /)>,
#      'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x1082af4d0>>,
#      'isinstance': <function isinstance(obj, class_or_tuple, /)>,
#      'issubclass': <function issubclass(cls, class_or_tuple, /)>,
#      'iter': <function iter>,
#      'aiter': <function aiter(async_iterable, /)>,
#      'len': <function len(obj, /)>,
#      'locals': <function locals()>,
#      'max': <function max>,
#      'min': <function min>,
#      'next': <function next>,
#      'anext': <function anext>,
#      'oct': <function oct(number, /)>,
#      'ord': <function ord(character, /)>,
#      'pow': <function pow(base, exp, mod=None)>,
#      'print': <function print(*args, sep=' ', end='\n', file=None, flush=False)>,
#      'repr': <function repr(obj, /)>,
#      'round': <function round(number, ndigits=None)>,
#      'setattr': <function setattr(obj, name, value, /)>,
#      'sorted': <function sorted(iterable, /, *, key=None, reverse=False)>,
#      'sum': <function sum(iterable, /, start=0)>,
#      'vars': <function vars>,
#      'None': None,
#      'Ellipsis': Ellipsis,
#      'NotImplemented': NotImplemented,
#      'False': False,
#      'True': True,
#      'bool': bool,
#      'memoryview': memoryview,
#      'bytearray': bytearray,
#      'bytes': bytes,
#      'classmethod': classmethod,
#      'complex': complex,
#      'dict': dict,
#      'enumerate': enumerate,
#      'filter': filter,
#      'float': float,
#      'frozenset': frozenset,
#      'property': property,
#      'int': int,
#      'list': list,
#      'map': map,
#      'object': object,
#      'range': range,
#      'reversed': reversed,
#      'set': set,
#      'slice': slice,
#      'staticmethod': staticmethod,
#      'str': str,
#      'super': super,
#      'tuple': tuple,
#      'type': type,
#      'zip': zip,
#      '__debug__': True,
#      'BaseException': BaseException,
#      'BaseExceptionGroup': BaseExceptionGroup,
#      'Exception': Exception,
#      'GeneratorExit': GeneratorExit,
#      'KeyboardInterrupt': KeyboardInterrupt,
#      'SystemExit': SystemExit,
#      'ArithmeticError': ArithmeticError,
#      'AssertionError': AssertionError,
#      'AttributeError': AttributeError,
#      'BufferError': BufferError,
#      'EOFError': EOFError,
#      'ImportError': ImportError,
#      'LookupError': LookupError,
#      'MemoryError': MemoryError,
#      'NameError': NameError,
#      'OSError': OSError,
#      'ReferenceError': ReferenceError,
#      'RuntimeError': RuntimeError,
#      'StopAsyncIteration': StopAsyncIteration,
#      'StopIteration': StopIteration,
#      'SyntaxError': SyntaxError,
#      'SystemError': SystemError,
#      'TypeError': TypeError,
#      'ValueError': ValueError,
#      'Warning': Warning,
#      'FloatingPointError': FloatingPointError,
#      'OverflowError': OverflowError,
#      'ZeroDivisionError': ZeroDivisionError,
#      'BytesWarning': BytesWarning,
#      'DeprecationWarning': DeprecationWarning,
#      'EncodingWarning': EncodingWarning,
#      'FutureWarning': FutureWarning,
#      'ImportWarning': ImportWarning,
#      'PendingDeprecationWarning': PendingDeprecationWarning,
#      'ResourceWarning': ResourceWarning,
#      'RuntimeWarning': RuntimeWarning,
#      'SyntaxWarning': SyntaxWarning,
#      'UnicodeWarning': UnicodeWarning,
#      'UserWarning': UserWarning,
#      'BlockingIOError': BlockingIOError,
#      'ChildProcessError': ChildProcessError,
#      'ConnectionError': ConnectionError,
#      'FileExistsError': FileExistsError,
#      'FileNotFoundError': FileNotFoundError,
#      'InterruptedError': InterruptedError,
#      'IsADirectoryError': IsADirectoryError,
#      'NotADirectoryError': NotADirectoryError,
#      'PermissionError': PermissionError,
#      'ProcessLookupError': ProcessLookupError,
#      'TimeoutError': TimeoutError,
#      'IndentationError': IndentationError,
#      '_IncompleteInputError': _IncompleteInputError,
#      'IndexError': IndexError,
#      'KeyError': KeyError,
#      'ModuleNotFoundError': ModuleNotFoundError,
#      'NotImplementedError': NotImplementedError,
#      'PythonFinalizationError': PythonFinalizationError,
#      'RecursionError': RecursionError,
#      'UnboundLocalError': UnboundLocalError,
#      'UnicodeError': UnicodeError,
#      'BrokenPipeError': BrokenPipeError,
#      'ConnectionAbortedError': ConnectionAbortedError,
#      'ConnectionRefusedError': ConnectionRefusedError,
#      'ConnectionResetError': ConnectionResetError,
#      'TabError': TabError,
#      'UnicodeDecodeError': UnicodeDecodeError,
#      'UnicodeEncodeError': UnicodeEncodeError,
#      'UnicodeTranslateError': UnicodeTranslateError,
#      'ExceptionGroup': ExceptionGroup,
#      'EnvironmentError': OSError,
#      'IOError': OSError,
#      'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#      'copyright': Copyright (c) 2001-2024 Python Software Foundation.
#      All Rights Reserved.
#
#      Copyright (c) 2000 BeOpen.com.
#      All Rights Reserved.
#
#      Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#      All Rights Reserved.
#
#      Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#      All Rights Reserved.,
#      'credits':     Thanks to CWI, CNRI, BeOpen, Zope Corporation, the Python Software
#          Foundation, and a cast of thousands for supporting Python
#          development.  See www.python.org for more information.,
#      'license': Type license() to see the full license text,
#      'help': Type help() for interactive help, or help(object) for help about object.,
#      'execfile': <function _pydev_bundle._pydev_execfile.execfile(file, glob=None, loc=None)>,
#      'runfile': <function _pydev_bundle.pydev_umd.runfile(filename, args=None, wdir=None, namespace=None)>,
#      '__IPYTHON__': True,
#      'display': <function IPython.core.display_functions.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, raw=False, clear=False, **kwargs)>,
#      'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x1085fd2b0>>}},
#    'errors': ['In cell: assert question_nine(["a","b"],"-") == "a-b"\nassert question -> invalid syntax (<string>, line 2)'],
#    'traceback': None,
#    'success': False},
#   'results': [{'question': 'question_one',
#     'assertion': 'assert question_one([1,2,2,3]) == 6',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_one',
#     'assertion': 'assert question_one([]) == 0',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_two',
#     'assertion': 'assert question_two([1,2,3]) == [3,2,1]',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_two',
#     'assertion': 'assert question_two([]) == []',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_three',
#     'assertion': 'assert question_three([1,2,2,3]) == {1:1,2:2,3:1}',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_three',
#     'assertion': 'assert question_three([]) == {}',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_four',
#     'assertion': 'assert question_four([[1,2],[3,4]]) == [1,2,3,4]',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_four',
#     'assertion': 'assert question_four([]) == []',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_five',
#     'assertion': "assert question_five({'a':1,'b':2,'c':1}) == {1:['a','c'],2:['b']}",
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_six',
#     'assertion': "assert question_six({'x':1,'y':2},{'y':3,'z':4}) == {'x':1,'y':5,'z':4}",
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_eight',
#     'assertion': 'assert question_eight("hello world") == ["hello","world"]',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_eight',
#     'assertion': 'assert question_eight("") == []',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_ten',
#     'assertion': 'assert question_ten("I love python") == 6',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_ten',
#     'assertion': 'assert question_ten("") == 0',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_eleven',
#     'assertion': 'assert question_eleven([1,2,3],[2,3,4]) == {2,3}',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_twelve',
#     'assertion': 'assert question_twelve([1,2,2,3,1]) == [1,2,3]',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_thirteen',
#     'assertion': 'assert question_thirteen([1,2,3]) == [1,4,9]',
#     'status': 'passed',
#     'error': None,
#     'score': 1},
#    {'question': 'question_fourteen',
#     'assertion': 'assert question_fourteen([1,2,3,4]) == [2,4]',
#     'status': 'passed',
#     'error': None,
#     'score': 1}]},
#  {'student_path': PosixPath('/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/submissions/python/student_answer_sheet.ipynb'),
#   'execution': {'namespace': {'name': 'student name',
#     'roll_number': 'student roll number',
#     'question_one': <function question_one(nums: list[int]) -> int>,
#     'question_two': <function question_two(xs: list) -> list>,
#     'question_three': <function question_three(xs: list) -> dict>,
#     'question_four': <function question_four(nested: list[list]) -> list>,
#     'question_five': <function question_five(d: dict) -> dict>,
#     'question_six': <function question_six(a: dict, b: dict) -> dict>,
#     'question_seven': <function question_seven(nums: list[int], k: int) -> list[int]>,
#     'question_eight': <function question_eight(s: str) -> list[str]>,
#     'question_nine': <function question_nine(words: list[str], sep: str = ' ') -> str>,
#     'question_ten': <function question_ten(sentence: str) -> int>,
#     'question_eleven': <function question_eleven(a: list, b: list) -> set>,
#     'question_twelve': <function question_twelve(xs: list) -> list>,
#     'question_thirteen': <function question_thirteen(nums: list[int]) -> list[int]>,
#     'question_fourteen': <function question_fourteen(nums: list[int]) -> list[int]>,
#     'question_fifteen': <function question_fifteen(values: list) -> 'pd.Series'>,
#     'question_sixteen': <function question_sixteen(df: 'pd.DataFrame') -> 'pd.DataFrame'>,
#     'question_seventeen': <function question_seventeen(a: 'pd.DataFrame', b: 'pd.DataFrame') -> 'pd.DataFrame'>,
#     'question_eighteen': <function question_eighteen(dfs: list) -> 'pd.DataFrame'>,
#     'question_nineteen': <function question_nineteen(df: 'pd.DataFrame') -> 'pd.DataFrame'>,
#     'question_twenty': <function question_twenty(df: 'pd.DataFrame', fill_value=0) -> 'pd.DataFrame'>,
#     '__builtins__': {'__name__': 'builtins',
#      '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.",
#      '__package__': '',
#      '__loader__': _frozen_importlib.BuiltinImporter,
#      '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#      '__build_class__': <function __build_class__>,
#      '__import__': <function __import__(name, globals=None, locals=None, fromlist=(), level=0)>,
#      'abs': <function abs(x, /)>,
#      'all': <function all(iterable, /)>,
#      'any': <function any(iterable, /)>,
#      'ascii': <function ascii(obj, /)>,
#      'bin': <function bin(number, /)>,
#      'breakpoint': <function breakpoint(*args, **kws)>,
#      'callable': <function callable(obj, /)>,
#      'chr': <function chr(i, /)>,
#      'compile': <function compile(source, filename, mode, flags=0, dont_inherit=False, optimize=-1, *, _feature_version=-1)>,
#      'delattr': <function delattr(obj, name, /)>,
#      'dir': <function dir>,
#      'divmod': <function divmod(x, y, /)>,
#      'eval': <function eval(source, /, globals=None, locals=None)>,
#      'exec': <function exec(source, /, globals=None, locals=None, *, closure=None)>,
#      'format': <function format(value, format_spec='', /)>,
#      'getattr': <function getattr>,
#      'globals': <function globals()>,
#      'hasattr': <function hasattr(obj, name, /)>,
#      'hash': <function hash(obj, /)>,
#      'hex': <function hex(number, /)>,
#      'id': <function id(obj, /)>,
#      'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x1082af4d0>>,
#      'isinstance': <function isinstance(obj, class_or_tuple, /)>,
#      'issubclass': <function issubclass(cls, class_or_tuple, /)>,
#      'iter': <function iter>,
#      'aiter': <function aiter(async_iterable, /)>,
#      'len': <function len(obj, /)>,
#      'locals': <function locals()>,
#      'max': <function max>,
#      'min': <function min>,
#      'next': <function next>,
#      'anext': <function anext>,
#      'oct': <function oct(number, /)>,
#      'ord': <function ord(character, /)>,
#      'pow': <function pow(base, exp, mod=None)>,
#      'print': <function print(*args, sep=' ', end='\n', file=None, flush=False)>,
#      'repr': <function repr(obj, /)>,
#      'round': <function round(number, ndigits=None)>,
#      'setattr': <function setattr(obj, name, value, /)>,
#      'sorted': <function sorted(iterable, /, *, key=None, reverse=False)>,
#      'sum': <function sum(iterable, /, start=0)>,
#      'vars': <function vars>,
#      'None': None,
#      'Ellipsis': Ellipsis,
#      'NotImplemented': NotImplemented,
#      'False': False,
#      'True': True,
#      'bool': bool,
#      'memoryview': memoryview,
#      'bytearray': bytearray,
#      'bytes': bytes,
#      'classmethod': classmethod,
#      'complex': complex,
#      'dict': dict,
#      'enumerate': enumerate,
#      'filter': filter,
#      'float': float,
#      'frozenset': frozenset,
#      'property': property,
#      'int': int,
#      'list': list,
#      'map': map,
#      'object': object,
#      'range': range,
#      'reversed': reversed,
#      'set': set,
#      'slice': slice,
#      'staticmethod': staticmethod,
#      'str': str,
#      'super': super,
#      'tuple': tuple,
#      'type': type,
#      'zip': zip,
#      '__debug__': True,
#      'BaseException': BaseException,
#      'BaseExceptionGroup': BaseExceptionGroup,
#      'Exception': Exception,
#      'GeneratorExit': GeneratorExit,
#      'KeyboardInterrupt': KeyboardInterrupt,
#      'SystemExit': SystemExit,
#      'ArithmeticError': ArithmeticError,
#      'AssertionError': AssertionError,
#      'AttributeError': AttributeError,
#      'BufferError': BufferError,
#      'EOFError': EOFError,
#      'ImportError': ImportError,
#      'LookupError': LookupError,
#      'MemoryError': MemoryError,
#      'NameError': NameError,
#      'OSError': OSError,
#      'ReferenceError': ReferenceError,
#      'RuntimeError': RuntimeError,
#      'StopAsyncIteration': StopAsyncIteration,
#      'StopIteration': StopIteration,
#      'SyntaxError': SyntaxError,
#      'SystemError': SystemError,
#      'TypeError': TypeError,
#      'ValueError': ValueError,
#      'Warning': Warning,
#      'FloatingPointError': FloatingPointError,
#      'OverflowError': OverflowError,
#      'ZeroDivisionError': ZeroDivisionError,
#      'BytesWarning': BytesWarning,
#      'DeprecationWarning': DeprecationWarning,
#      'EncodingWarning': EncodingWarning,
#      'FutureWarning': FutureWarning,
#      'ImportWarning': ImportWarning,
#      'PendingDeprecationWarning': PendingDeprecationWarning,
#      'ResourceWarning': ResourceWarning,
#      'RuntimeWarning': RuntimeWarning,
#      'SyntaxWarning': SyntaxWarning,
#      'UnicodeWarning': UnicodeWarning,
#      'UserWarning': UserWarning,
#      'BlockingIOError': BlockingIOError,
#      'ChildProcessError': ChildProcessError,
#      'ConnectionError': ConnectionError,
#      'FileExistsError': FileExistsError,
#      'FileNotFoundError': FileNotFoundError,
#      'InterruptedError': InterruptedError,
#      'IsADirectoryError': IsADirectoryError,
#      'NotADirectoryError': NotADirectoryError,
#      'PermissionError': PermissionError,
#      'ProcessLookupError': ProcessLookupError,
#      'TimeoutError': TimeoutError,
#      'IndentationError': IndentationError,
#      '_IncompleteInputError': _IncompleteInputError,
#      'IndexError': IndexError,
#      'KeyError': KeyError,
#      'ModuleNotFoundError': ModuleNotFoundError,
#      'NotImplementedError': NotImplementedError,
#      'PythonFinalizationError': PythonFinalizationError,
#      'RecursionError': RecursionError,
#      'UnboundLocalError': UnboundLocalError,
#      'UnicodeError': UnicodeError,
#      'BrokenPipeError': BrokenPipeError,
#      'ConnectionAbortedError': ConnectionAbortedError,
#      'ConnectionRefusedError': ConnectionRefusedError,
#      'ConnectionResetError': ConnectionResetError,
#      'TabError': TabError,
#      'UnicodeDecodeError': UnicodeDecodeError,
#      'UnicodeEncodeError': UnicodeEncodeError,
#      'UnicodeTranslateError': UnicodeTranslateError,
#      'ExceptionGroup': ExceptionGroup,
#      'EnvironmentError': OSError,
#      'IOError': OSError,
#      'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#      'copyright': Copyright (c) 2001-2024 Python Software Foundation.
#      All Rights Reserved.
#
#      Copyright (c) 2000 BeOpen.com.
#      All Rights Reserved.
#
#      Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#      All Rights Reserved.
#
#      Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#      All Rights Reserved.,
#      'credits':     Thanks to CWI, CNRI, BeOpen, Zope Corporation, the Python Software
#          Foundation, and a cast of thousands for supporting Python
#          development.  See www.python.org for more information.,
#      'license': Type license() to see the full license text,
#      'help': Type help() for interactive help, or help(object) for help about object.,
#      'execfile': <function _pydev_bundle._pydev_execfile.execfile(file, glob=None, loc=None)>,
#      'runfile': <function _pydev_bundle.pydev_umd.runfile(filename, args=None, wdir=None, namespace=None)>,
#      '__IPYTHON__': True,
#      'display': <function IPython.core.display_functions.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, raw=False, clear=False, **kwargs)>,
#      'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x1085fd2b0>>}},
#    'errors': [],
#    'traceback': None,
#    'success': True},
#   'results': [{'question': 'question_one',
#     'assertion': 'assert question_one([1,2,2,3]) == 6',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_one',
#     'assertion': 'assert question_one([]) == 0',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_two',
#     'assertion': 'assert question_two([1,2,3]) == [3,2,1]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_two',
#     'assertion': 'assert question_two([]) == []',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_three',
#     'assertion': 'assert question_three([1,2,2,3]) == {1:1,2:2,3:1}',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_three',
#     'assertion': 'assert question_three([]) == {}',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_four',
#     'assertion': 'assert question_four([[1,2],[3,4]]) == [1,2,3,4]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_four',
#     'assertion': 'assert question_four([]) == []',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_five',
#     'assertion': "assert question_five({'a':1,'b':2,'c':1}) == {1:['a','c'],2:['b']}",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_six',
#     'assertion': "assert question_six({'x':1,'y':2},{'y':3,'z':4}) == {'x':1,'y':5,'z':4}",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_eight',
#     'assertion': 'assert question_eight("hello world") == ["hello","world"]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_eight',
#     'assertion': 'assert question_eight("") == []',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_ten',
#     'assertion': 'assert question_ten("I love python") == 6',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_ten',
#     'assertion': 'assert question_ten("") == 0',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_eleven',
#     'assertion': 'assert question_eleven([1,2,3],[2,3,4]) == {2,3}',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_twelve',
#     'assertion': 'assert question_twelve([1,2,2,3,1]) == [1,2,3]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_thirteen',
#     'assertion': 'assert question_thirteen([1,2,3]) == [1,4,9]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0},
#    {'question': 'question_fourteen',
#     'assertion': 'assert question_fourteen([1,2,3,4]) == [2,4]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/comparison/comparison_service.py", line 20, in run_assertions\n    exec(code, student_namespace)\n    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "<string>", line 1, in <module>\nAssertionError\n',
#     'score': 0}]}]

# %% [markdown]
# # EOF
