# %% [markdown]
# # Basic Python Flow

# %%
import sys
from pathlib import Path

# current notebook is inside ./data/python_example1/
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent.parent     # go up two levels to project root

sys.path.append(str(PROJECT_ROOT / "src"))

from instantgrade import Evaluator

# %%
from instantgrade.utils.io_utils import generate_student_notebook

generate_student_notebook(
    instructor_path="./control_flow_assessment.ipynb",
    output_path="./submissions/student_notebook.ipynb"
)
# Out:
# ✅ Student notebook generated at: submissions/student_notebook.ipynb

# %%
from instantgrade.evaluator import Evaluator

eval = Evaluator(
    solution_file_path="./pandas_practice.ipynb",
    submission_folder_path="./submissions",
    use_docker=True,       # or False for local test mode
    log_path="./logs",
    log_level="normal",
)

report = eval.run()
eval.to_html("./reports/evaluation_report.html")
# Out:
# 12:30:55 | INFO     | Starting evaluation pipeline...
# 12:30:55 | INFO     | Loading instructor solution...
# 12:30:55 | INFO     | Loaded 20 questions.
# 12:30:55 | INFO     | Discovered 49 submissions to grade.
# 12:30:55 | INFO     | Starting Docker-based evaluation pipeline...
# 12:30:55 | INFO     | [1/49] Grading: 2423350_Nitin.Sahsani (2).ipynb
# 12:30:55 | INFO     | [Docker] Starting grading for 2423350_Nitin.Sahsani (2).ipynb
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Starting grading...
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'describe_numeric', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'fill_missing_with_mean', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df', 'select_column']
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Final resolved student identity -> name='Nitin Sahsani', roll='2423350'
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: select_column
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:30:56 | INFO     | [2423350_Nitin.Sahsani (2).ipynb][docker] [grader] results.json written with 49 rows.
# 12:30:56 | INFO     | [2/49] Grading: ArunMG(2423360).ipynb
# 12:30:56 | INFO     | [Docker] Starting grading for ArunMG(2423360).ipynb
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Starting grading...
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'drop_duplicates_by_cols', 'fill_missing_college', 'fill_missing_with_mean', 'filter_profit_range', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df']
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Final resolved student identity -> name='Arun Murari Gottipati', roll='2423360'
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: select_column
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:30:57 | INFO     | [ArunMG(2423360).ipynb][docker] [grader] results.json written with 35 rows.
# 12:30:57 | INFO     | [3/49] Grading: Harsh CIA.ipynb
# 12:30:57 | INFO     | [Docker] Starting grading for Harsh CIA.ipynb
# 12:30:57 | INFO     | [Harsh CIA.ipynb][docker] [grader] Starting grading...
# 12:30:57 | INFO     | [Harsh CIA.ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:30:57 | INFO     | [Harsh CIA.ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'fill_missing_with_mean', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df']
# 12:30:57 | INFO     | [Harsh CIA.ipynb][docker] [grader] Final resolved student identity -> name='Harsh Mittal', roll='2423373'
# 12:30:57 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:30:57 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:30:57 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:30:57 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:30:57 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: select_column
# 12:30:57 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:30:57 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] Count of NaN values in each column:
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] a    1
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] b    2
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] c    0
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] dtype: int64
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker]
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] DataFrame after dropping NaN rows and resetting index:
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker]      x     y
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] 0  1.0  10.0
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:30:58 | INFO     | [Harsh CIA.ipynb][docker] [grader] results.json written with 52 rows.
# 12:30:58 | INFO     | [4/49] Grading: MAYUR 2423358 (1).ipynb
# 12:30:58 | INFO     | [Docker] Starting grading for MAYUR 2423358 (1).ipynb
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Starting grading...
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Namespace after execution: ['StringIO', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'describe_numeric', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_with_mean', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'name', 'np', 'pd', 'roll_number', 'sample_df', 'select_column']
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Final resolved student identity -> name='Mayur garg', roll='2423358'
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] <class 'pandas.core.frame.DataFrame'>
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] RangeIndex: 2 entries, 0 to 1
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] Data columns (total 3 columns):
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker]  #   Column  Non-Null Count  Dtype
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] ---  ------  --------------  -----
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker]  0   x       2 non-null      int64
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker]  1   y       2 non-null      int64
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker]  2   z       2 non-null      int64
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] dtypes: int64(3)
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] memory usage: 180.0 bytes
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: select_column
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:30:58 | INFO     | [MAYUR 2423358 (1).ipynb][docker] [grader] results.json written with 45 rows.
# 12:30:58 | INFO     | [5/49] Grading: Nishant_Kumar(2423349).ipynb
# 12:30:58 | INFO     | [Docker] Starting grading for Nishant_Kumar(2423349).ipynb
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Starting grading...
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'fill_missing_with_mean', 'filter_by_threshold', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df', 'select_column']
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Final resolved student identity -> name='NISHANT KUMAR', roll='2423349'
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: select_column
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:30:59 | INFO     | [Nishant_Kumar(2423349).ipynb][docker] [grader] results.json written with 43 rows.
# 12:30:59 | INFO     | [6/49] Grading: Sarthak_Chaudhary_2423346.ipynb
# 12:30:59 | INFO     | [Docker] Starting grading for Sarthak_Chaudhary_2423346.ipynb
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Starting grading...
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'describe_numeric', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'fill_missing_with_mean', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df', 'select_column']
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Final resolved student identity -> name='Sarthak Chaudhary', roll='2423346'
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: select_column
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:30:59 | INFO     | [Sarthak_Chaudhary_2423346.ipynb][docker] [grader] results.json written with 48 rows.
# 12:30:59 | INFO     | [7/49] Grading: SohamUdaySahasrabudhe2423363.ipynb
# 12:30:59 | INFO     | [Docker] Starting grading for SohamUdaySahasrabudhe2423363.ipynb
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Starting grading...
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'convert_to_datetime', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df']
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Final resolved student identity -> name='Soham Uday Sahasrabudhe', roll='2423363'
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: select_column
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:31:00 | INFO     | [SohamUdaySahasrabudhe2423363.ipynb][docker] [grader] results.json written with 42 rows.
# 12:31:00 | INFO     | [8/49] Grading: Untitled.ipynb
# 12:31:00 | INFO     | [Docker] Starting grading for Untitled.ipynb
# 12:31:01 | INFO     | [Untitled.ipynb][docker] [grader] Starting grading...
# 12:31:01 | INFO     | [Untitled.ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:31:01 | INFO     | [Untitled.ipynb][docker] [grader] Namespace after execution: []
# 12:31:01 | INFO     | [Untitled.ipynb][docker] [grader] Missing name/roll in namespace, scanning code cells...
# 12:31:01 | INFO     | [Untitled.ipynb][docker] [grader] Final resolved student identity -> name='student name', roll='student roll number'
# 12:31:01 | INFO     | [Untitled.ipynb][docker] [grader] ❌ Fatal: student identity still matches instructor defaults. Skipping assertions.
# 12:31:01 | INFO     | [9/49] Grading: Urvi Kamble.ipynb
# 12:31:01 | INFO     | [Docker] Starting grading for Urvi Kamble.ipynb
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Starting grading...
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'describe_numeric', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'fill_missing_with_mean', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df', 'select_column']
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Final resolved student identity -> name='Urvi Kamble', roll='2423383'
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: select_column
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:31:01 | INFO     | [Urvi Kamble.ipynb][docker] [grader] results.json written with 51 rows.
# 12:31:01 | INFO     | [10/49] Grading: Vaishnavi Kavishetti 2423381 (1).ipynb
# 12:31:01 | INFO     | [Docker] Starting grading for Vaishnavi Kavishetti 2423381 (1).ipynb
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Starting grading...
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'convert_to_datetime', 'describe_numeric', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'fill_missing_with_mean', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'select_column']
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Final resolved student identity -> name='Vaishnavi Santosh Kavishetti', roll='2423381'
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: select_column
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:31:02 | INFO     | [Vaishnavi Kavishetti 2423381 (1).ipynb][docker] [grader] results.json written with 48 rows.
# 12:31:02 | INFO     | [11/49] Grading: VanshRohida2423372 (1).ipynb
# 12:31:02 | INFO     | [Docker] Starting grading for VanshRohida2423372 (1).ipynb
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Starting grading...
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'describe_numeric', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df', 'select_column']
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Final resolved student identity -> name='Vansh Rohida', roll='2423372'
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: select_column
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:31:02 | INFO     | [VanshRohida2423372 (1).ipynb][docker] [grader] results.json written with 50 rows.
# 12:31:03 | INFO     | [12/49] Grading: rohan_64.ipynb
# 12:31:03 | INFO     | [Docker] Starting grading for rohan_64.ipynb
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Starting grading...
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Namespace after execution: ['StringIO', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'describe_numeric', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'fill_missing_with_mean', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df', 'select_column']
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Final resolved student identity -> name='RohanGM', roll='2423364'
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: select_column
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:31:03 | INFO     | [rohan_64.ipynb][docker] [grader] results.json written with 51 rows.
# 12:31:03 | INFO     | [13/49] Grading: student_notebook (1) (1).ipynb
# 12:31:03 | INFO     | [Docker] Starting grading for student_notebook (1) (1).ipynb
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Starting grading...
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'describe_numeric', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'fill_missing_with_mean', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df', 'select_column']
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Final resolved student identity -> name='Kanishka_Singh', roll='2423376'
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: select_column
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:31:04 | INFO     | [student_notebook (1) (1).ipynb][docker] [grader] results.json written with 42 rows.
# 12:31:04 | INFO     | [14/49] Grading: student_notebook (1)(1).ipynb
# 12:31:04 | INFO     | [Docker] Starting grading for student_notebook (1)(1).ipynb
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Starting grading...
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'describe_numeric', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df', 'select_column']
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Final resolved student identity -> name='Johann Karl', roll='2423382'
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: select_column
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:31:04 | INFO     | [student_notebook (1)(1).ipynb][docker] [grader] results.json written with 46 rows.
# 12:31:04 | INFO     | [15/49] Grading: student_notebook (1)(10).ipynb
# 12:31:04 | INFO     | [Docker] Starting grading for student_notebook (1)(10).ipynb
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Starting grading...
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'count_missing_values', 'drop_duplicates_by_cols', 'filter_by_threshold', 'get_dataframe_info', 'groupby_team_agg', 'load_csv_string', 'name', 'np', 'pd', 'roll_number', 'sample_df']
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Final resolved student identity -> name='vikram sinha', roll='2423359'
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: select_column
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:31:05 | INFO     | [student_notebook (1)(10).ipynb][docker] [grader] Evaluating question: convert_to_datetime
# ...
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 1  2.0  NaN  10.0   beta
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 2  NaN  7.0  11.0  gamma
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 3  4.0  8.0   NaN  delta
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ------------------------------
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ## 📊 Column Means Calculated:
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] A     2.333333
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] B     6.666667
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] C    10.000000
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] dtype: float64
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ------------------------------
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ## ✅ Imputed DataFrame:
# 12:31:26 | INFO     | [student_notebook.ipynb][docker]           A         B     C      D
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 0  1.000000  5.000000   9.0  alpha
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 1  2.000000  6.666667  10.0   beta
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 2  2.333333  7.000000  11.0  gamma
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 3  4.000000  8.000000  10.0  delta
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ## Original DataFrame
# 12:31:26 | INFO     | [student_notebook.ipynb][docker]       Name  Score1  Score2
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 0    Alice      55      70
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 1      Bob      30      65
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 2  Charlie      60      45
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 3    David      45      55
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 4      Eve      35      80
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 5    Frank      80      90
# 12:31:26 | INFO     | [student_notebook.ipynb][docker]
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ------------------------------
# 12:31:26 | INFO     | [student_notebook.ipynb][docker]
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ## Result DataFrame (Filtered & Calculated)
# 12:31:26 | INFO     | [student_notebook.ipynb][docker]     Name  AverageScore
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 0  Alice          62.5
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 3  David          50.0
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 5  Frank          85.0
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ### 📊 Original DataFrame
# 12:31:26 | INFO     | [student_notebook.ipynb][docker]       Name    Age  Score
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 0    Alice   30.0     85
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 1      Bob    NaN     90
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 2  Charlie  150.0     78
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 3    David   45.0     92
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 4      Eve   22.0     88
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 5    Frank    NaN     75
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 6    Grace  105.0     80
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ----------------------------------------
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] Original Median Age (used for imputation): 45.0
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ----------------------------------------
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ### ✨ Cleaned DataFrame
# 12:31:26 | INFO     | [student_notebook.ipynb][docker]     Name   Age  Score
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 0  Alice  30.0     85
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 1    Bob  45.0     90
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 3  David  45.0     92
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 4    Eve  22.0     88
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 5  Frank  45.0     75
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] ----------------------------------------
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_column', 'clean_age_data', 'convert_to_datetime', 'data', 'describe_numeric', 'df', 'df_cleaned', 'df_imputed', 'df_original', 'df_result', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'fill_missing_with_mean', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'numeric_cols_means', 'pd', 'process_scores', 'roll_number', 'sample_df']
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Final resolved student identity -> name='devansh', roll='2423366'
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: select_column
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] <student_cell_30>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# 12:31:26 | INFO     | [student_notebook.ipynb][docker]
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
# 12:31:26 | INFO     | [student_notebook.ipynb][docker]
# 12:31:26 | INFO     | [student_notebook.ipynb][docker]
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:31:26 | INFO     | [student_notebook.ipynb][docker]              Age       Salary
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] count   4.000000      4.00000
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] mean   29.500000  54250.00000
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] std     4.203173   4349.32945
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] min    25.000000  50000.00000
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 25%    27.250000  51500.00000
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 50%    29.000000  53500.00000
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] 75%    31.250000  56250.00000
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] max    35.000000  60000.00000
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:31:26 | INFO     | [student_notebook.ipynb][docker] [grader] results.json written with 53 rows.
# 12:31:26 | INFO     | [48/49] Grading: student_notebook2423343.ipynb
# 12:31:26 | INFO     | [Docker] Starting grading for student_notebook2423343.ipynb
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Starting grading...
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'count_missing_values', 'describe_numeric', 'drop_duplicates_by_cols', 'fill_missing_college', 'fill_missing_with_mean', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_summary_stats', 'group_and_calculate_mean', 'group_by_mean', 'groupby_team_agg', 'name', 'np', 'pd', 'roll_number', 'sample_df']
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Final resolved student identity -> name='Aarav Danani', roll='2423343'
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: select_column
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:31:26 | INFO     | [student_notebook2423343.ipynb][docker] [grader] results.json written with 45 rows.
# 12:31:27 | INFO     | [49/49] Grading: student_notebook_solved.ipynb
# 12:31:27 | INFO     | [Docker] Starting grading for student_notebook_solved.ipynb
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Starting grading...
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Instructor defaults -> name='student name', roll='student roll number'
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Namespace after execution: ['StringIO', 'add_updated_salary', 'advanced_filter_and_create', 'clean_age_data', 'convert_to_datetime', 'describe_numeric', 'drop_duplicates_by_cols', 'drop_rows_with_nan', 'fill_missing_college', 'fill_missing_with_mean', 'filter_by_threshold', 'filter_profit_range', 'get_dataframe_info', 'get_first_n_rows', 'get_summary_stats', 'group_by_mean', 'groupby_team_agg', 'load_csv_string', 'merge_dataframes', 'name', 'np', 'pd', 'roll_number', 'sample_df', 'select_column']
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Final resolved student identity -> name='Lalit Mohan Kumar', roll='2423375'
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: load_csv_string
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: get_dataframe_info
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: get_first_n_rows
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: describe_numeric
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: select_column
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: filter_by_threshold
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: count_missing_values
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: drop_rows_with_nan
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: fill_missing_with_mean
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: group_by_mean
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: merge_dataframes
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: convert_to_datetime
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: drop_duplicates_by_cols
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: fill_missing_college
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: add_updated_salary
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: filter_profit_range
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: get_summary_stats
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: groupby_team_agg
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: advanced_filter_and_create
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] Evaluating question: clean_age_data
# 12:31:27 | INFO     | [student_notebook_solved.ipynb][docker] [grader] results.json written with 51 rows.
# 12:31:27 | INFO     | Execution phase completed successfully.
# 12:31:27 | INFO     | [Reporting] Processed 2124 result rows.
# 12:31:27 | INFO     | Report generation complete.
# 12:31:27 | INFO     | Total evaluation completed in 32.09s.
# 12:31:27 | INFO     | HTML report generated at: reports/evaluation_report.html
# 'reports/evaluation_report.html'

# %%
report.executed_results
# Out:
# [{'student_path': PosixPath('submissions/sample_solutions copy.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='student name', roll='student roll number'\n[grader] Namespace after execution: ['average_of_three', 'check_number', 'check_password', 'count_letter', 'even_numbers_1_to_n', 'even_or_odd', 'larger_number', 'name', 'numbers_1_to_n', 'roll_number', 'square_number', 'squares_1_to_n', 'sum_1_to_n']\n[grader] Final resolved student identity -> name='student name', roll='student roll number'\n[grader] ❌ Fatal: student identity still matches instructor defaults. Skipping assertions.",
#    'docker_stderr': '',
#    'elapsed': 15.05,
#    'student_meta': {'name': 'student name',
#     'roll_number': 'student roll number'}},
#   'results': [{'question': '_identity_check_',
#     'assertion': '[missing student identity]',
#     'status': 'failed',
#     'error': "Student notebook missing personalized name/roll_number. Please define:\n\nname = 'Your Name'\nroll_number = 'Your Roll Number'\n",
#     'score': 0,
#     'description': 'Student did not customize name/roll_number.'}]},
#  {'student_path': PosixPath('submissions/sample_solutions partial.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='student name', roll='student roll number'\n[grader] Namespace after execution: ['average_of_three', 'check_number', 'check_password', 'count_letter', 'even_numbers_1_to_n', 'even_or_odd', 'larger_number', 'name', 'numbers_1_to_n', 'roll_number', 'square_number', 'squares_1_to_n', 'sum_1_to_n']\n[grader] Final resolved student identity -> name='partial name', roll='partial roll number'\n[grader] Evaluating question: check_number\n[grader] Evaluating question: numbers_1_to_n\n[grader] Evaluating question: even_numbers_1_to_n\n[grader] Evaluating question: square_number\n[grader] Evaluating question: check_password\n[grader] Evaluating question: larger_number\n[grader] Evaluating question: even_or_odd\n[grader] Evaluating question: sum_1_to_n\n[grader] Evaluating question: squares_1_to_n\n[grader] Evaluating question: count_letter\n[grader] Evaluating question: average_of_three\n[grader] results.json written with 24 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.62,
#    'student_meta': {'name': 'partial name',
#     'roll_number': 'partial roll number'}},
#   'results': [{'question': 'check_number',
#     'assertion': "assert check_number(5) == 'Positive'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'check_number',
#     'assertion': "assert check_number(-3) == 'Negative'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'check_number',
#     'assertion': "assert check_number(0) == 'Zero'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'numbers_1_to_n',
#     'assertion': 'assert numbers_1_to_n(5) == [1, 2, 3, 4, 5]',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': 'Example if n = 5 then\n**Return:** `[1, 2, 3, 4, 5]`'},
#    {'question': 'even_numbers_1_to_n',
#     'assertion': 'assert even_numbers_1_to_n(11) == [2, 4, 6, 8, 10]',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': 'Example if n = 11 then\n**Return:** `[2, 4, 6, 8, 10]`'},
#    {'question': 'square_number',
#     'assertion': 'assert square_number(4) == 16',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** For input `4`, return `16`'},
#    {'question': 'square_number',
#     'assertion': 'assert square_number(0) == 0',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** For input `4`, return `16`'},
#    {'question': 'check_password',
#     'assertion': "assert check_password('python') == 'Access Granted'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'check_password',
#     'assertion': "assert check_password('PYTHON') == 'Access Denied'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'check_password',
#     'assertion': "assert check_password('java') == 'Access Denied'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(4, 9) == 9',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(10, 3) == 10',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(5, 5) == 5',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'even_or_odd',
#     'assertion': "assert even_or_odd(2) == 'Even'",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `4` → `'Even'`"},
#    {'question': 'even_or_odd',
#     'assertion': "assert even_or_odd(3) == 'Odd'",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `4` → `'Even'`"},
#    {'question': 'sum_1_to_n',
#     'assertion': 'assert sum_1_to_n(5) == 15',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `5` → `15`\nbecause 1+2'},
#    {'question': 'sum_1_to_n',
#     'assertion': 'assert sum_1_to_n(10) == 55',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `5` → `15`\nbecause 1+2'},
#    {'question': 'squares_1_to_n',
#     'assertion': 'assert squares_1_to_n(5) == [1, 4, 9, 16, 25]',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': 'if n is 5\n**Return:** `[1, 4, 9, 16, 25]`'},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('banana', 'a') == 3",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('apple', 'p') == 2",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('python', 'z') == 0",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'average_of_three',
#     'assertion': 'assert round(average_of_three(4, 8, 10), 2) == 7.33',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nTypeError: type NoneType doesn\'t define __round__ method\n',
#     'score': 0,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'},
#    {'question': 'average_of_three',
#     'assertion': 'assert average_of_three(3, 3, 3) == 3',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'},
#    {'question': 'average_of_three',
#     'assertion': 'assert average_of_three(10, 0, 5) == 5',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'}]},
#  {'student_path': PosixPath('submissions/sample_solutions.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='student name', roll='student roll number'\n[grader] Namespace after execution: ['average_of_three', 'check_number', 'check_password', 'count_letter', 'even_numbers_1_to_n', 'even_or_odd', 'larger_number', 'name', 'numbers_1_to_n', 'roll_number', 'square_number', 'squares_1_to_n', 'sum_1_to_n']\n[grader] Final resolved student identity -> name='student name', roll='student roll number'\n[grader] ❌ Fatal: student identity still matches instructor defaults. Skipping assertions.",
#    'docker_stderr': '',
#    'elapsed': 0.65,
#    'student_meta': {'name': 'student name',
#     'roll_number': 'student roll number'}},
#   'results': [{'question': '_identity_check_',
#     'assertion': '[missing student identity]',
#     'status': 'failed',
#     'error': "Student notebook missing personalized name/roll_number. Please define:\n\nname = 'Your Name'\nroll_number = 'Your Roll Number'\n",
#     'score': 0,
#     'description': 'Student did not customize name/roll_number.'}]},
#  {'student_path': PosixPath('submissions/sample_solutions_1.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='student name', roll='student roll number'\n[grader] Namespace after execution: ['average_of_three', 'check_number', 'check_password', 'count_letter', 'even_numbers_1_to_n', 'even_or_odd', 'larger_number', 'name', 'numbers_1_to_n', 'roll_number', 'square_number', 'squares_1_to_n', 'sum_1_to_n']\n[grader] Final resolved student identity -> name='Test 1', roll='Test 1 roll number'\n[grader] Evaluating question: check_number\n[grader] Evaluating question: numbers_1_to_n\n[grader] Evaluating question: even_numbers_1_to_n\n[grader] Evaluating question: square_number\n[grader] Evaluating question: check_password\n[grader] Evaluating question: larger_number\n[grader] Evaluating question: even_or_odd\n[grader] Evaluating question: sum_1_to_n\n[grader] Evaluating question: squares_1_to_n\n[grader] Evaluating question: count_letter\n[grader] Evaluating question: average_of_three\n[grader] results.json written with 24 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.63,
#    'student_meta': {'name': 'Test 1', 'roll_number': 'Test 1 roll number'}},
#   'results': [{'question': 'check_number',
#     'assertion': "assert check_number(5) == 'Positive'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'check_number',
#     'assertion': "assert check_number(-3) == 'Negative'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'check_number',
#     'assertion': "assert check_number(0) == 'Zero'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'numbers_1_to_n',
#     'assertion': 'assert numbers_1_to_n(5) == [1, 2, 3, 4, 5]',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': 'Example if n = 5 then\n**Return:** `[1, 2, 3, 4, 5]`'},
#    {'question': 'even_numbers_1_to_n',
#     'assertion': 'assert even_numbers_1_to_n(11) == [2, 4, 6, 8, 10]',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': 'Example if n = 11 then\n**Return:** `[2, 4, 6, 8, 10]`'},
#    {'question': 'square_number',
#     'assertion': 'assert square_number(4) == 16',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** For input `4`, return `16`'},
#    {'question': 'square_number',
#     'assertion': 'assert square_number(0) == 0',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** For input `4`, return `16`'},
#    {'question': 'check_password',
#     'assertion': "assert check_password('python') == 'Access Granted'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'check_password',
#     'assertion': "assert check_password('PYTHON') == 'Access Denied'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'check_password',
#     'assertion': "assert check_password('java') == 'Access Denied'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(4, 9) == 9',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(10, 3) == 10',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(5, 5) == 5',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'even_or_odd',
#     'assertion': "assert even_or_odd(2) == 'Even'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `4` → `'Even'`"},
#    {'question': 'even_or_odd',
#     'assertion': "assert even_or_odd(3) == 'Odd'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `4` → `'Even'`"},
#    {'question': 'sum_1_to_n',
#     'assertion': 'assert sum_1_to_n(5) == 15',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `5` → `15`\nbecause 1+2'},
#    {'question': 'sum_1_to_n',
#     'assertion': 'assert sum_1_to_n(10) == 55',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `5` → `15`\nbecause 1+2'},
#    {'question': 'squares_1_to_n',
#     'assertion': 'assert squares_1_to_n(5) == [1, 4, 9, 16, 25]',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': 'if n is 5\n**Return:** `[1, 4, 9, 16, 25]`'},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('banana', 'a') == 3",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('apple', 'p') == 2",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('python', 'z') == 0",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'average_of_three',
#     'assertion': 'assert round(average_of_three(4, 8, 10), 2) == 7.33',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'},
#    {'question': 'average_of_three',
#     'assertion': 'assert average_of_three(3, 3, 3) == 3',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'},
#    {'question': 'average_of_three',
#     'assertion': 'assert average_of_three(10, 0, 5) == 5',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'}]},
#  {'student_path': PosixPath('submissions/sample_solutions_2.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='student name', roll='student roll number'\n[grader] Namespace after execution: ['average_of_three', 'check_number', 'check_password', 'count_letter', 'even_numbers_1_to_n', 'even_or_odd', 'larger_number', 'name', 'numbers_1_to_n', 'roll_number', 'square_number', 'squares_1_to_n', 'sum_1_to_n']\n[grader] Final resolved student identity -> name='Test 2', roll='Test 2 roll number'\n[grader] Evaluating question: check_number\n[grader] Evaluating question: numbers_1_to_n\n[grader] Evaluating question: even_numbers_1_to_n\n[grader] Evaluating question: square_number\n[grader] Evaluating question: check_password\n[grader] Evaluating question: larger_number\n[grader] Evaluating question: even_or_odd\n[grader] Evaluating question: sum_1_to_n\n[grader] Evaluating question: squares_1_to_n\n[grader] Evaluating question: count_letter\n[grader] Evaluating question: average_of_three\n[grader] results.json written with 24 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.6,
#    'student_meta': {'name': 'Test 2', 'roll_number': 'Test 2 roll number'}},
#   'results': [{'question': 'check_number',
#     'assertion': "assert check_number(5) == 'Positive'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'check_number',
#     'assertion': "assert check_number(-3) == 'Negative'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'check_number',
#     'assertion': "assert check_number(0) == 'Zero'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'numbers_1_to_n',
#     'assertion': 'assert numbers_1_to_n(5) == [1, 2, 3, 4, 5]',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': 'Example if n = 5 then\n**Return:** `[1, 2, 3, 4, 5]`'},
#    {'question': 'even_numbers_1_to_n',
#     'assertion': 'assert even_numbers_1_to_n(11) == [2, 4, 6, 8, 10]',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': 'Example if n = 11 then\n**Return:** `[2, 4, 6, 8, 10]`'},
#    {'question': 'square_number',
#     'assertion': 'assert square_number(4) == 16',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** For input `4`, return `16`'},
#    {'question': 'square_number',
#     'assertion': 'assert square_number(0) == 0',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** For input `4`, return `16`'},
#    {'question': 'check_password',
#     'assertion': "assert check_password('python') == 'Access Granted'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'check_password',
#     'assertion': "assert check_password('PYTHON') == 'Access Denied'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'check_password',
#     'assertion': "assert check_password('java') == 'Access Denied'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(4, 9) == 9',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(10, 3) == 10',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(5, 5) == 5',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'even_or_odd',
#     'assertion': "assert even_or_odd(2) == 'Even'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `4` → `'Even'`"},
#    {'question': 'even_or_odd',
#     'assertion': "assert even_or_odd(3) == 'Odd'",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `4` → `'Even'`"},
#    {'question': 'sum_1_to_n',
#     'assertion': 'assert sum_1_to_n(5) == 15',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `5` → `15`\nbecause 1+2'},
#    {'question': 'sum_1_to_n',
#     'assertion': 'assert sum_1_to_n(10) == 55',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `5` → `15`\nbecause 1+2'},
#    {'question': 'squares_1_to_n',
#     'assertion': 'assert squares_1_to_n(5) == [1, 4, 9, 16, 25]',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': 'if n is 5\n**Return:** `[1, 4, 9, 16, 25]`'},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('banana', 'a') == 3",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('apple', 'p') == 2",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('python', 'z') == 0",
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'average_of_three',
#     'assertion': 'assert round(average_of_three(4, 8, 10), 2) == 7.33',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'},
#    {'question': 'average_of_three',
#     'assertion': 'assert average_of_three(3, 3, 3) == 3',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'},
#    {'question': 'average_of_three',
#     'assertion': 'assert average_of_three(10, 0, 5) == 5',
#     'status': 'passed',
#     'error': None,
#     'score': 1,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'}]},
#  {'student_path': PosixPath('submissions/student_notebook copy.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='student name', roll='student roll number'\n[grader] Namespace after execution: ['average_of_three', 'check_number', 'check_password', 'count_letter', 'even_numbers_1_to_n', 'even_or_odd', 'larger_number', 'name', 'numbers_1_to_n', 'roll_number', 'square_number', 'squares_1_to_n', 'sum_1_to_n']\n[grader] Final resolved student identity -> name='zero', roll='zero roll number'\n[grader] Evaluating question: check_number\n[grader] Evaluating question: numbers_1_to_n\n[grader] Evaluating question: even_numbers_1_to_n\n[grader] Evaluating question: square_number\n[grader] Evaluating question: check_password\n[grader] Evaluating question: larger_number\n[grader] Evaluating question: even_or_odd\n[grader] Evaluating question: sum_1_to_n\n[grader] Evaluating question: squares_1_to_n\n[grader] Evaluating question: count_letter\n[grader] Evaluating question: average_of_three\n[grader] results.json written with 24 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.6,
#    'student_meta': {'name': 'zero', 'roll_number': 'zero roll number'}},
#   'results': [{'question': 'check_number',
#     'assertion': "assert check_number(5) == 'Positive'",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'check_number',
#     'assertion': "assert check_number(-3) == 'Negative'",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'check_number',
#     'assertion': "assert check_number(0) == 'Zero'",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Return:** A string such as `'Positive'`, `'Negative'`, or `'Zero'`"},
#    {'question': 'numbers_1_to_n',
#     'assertion': 'assert numbers_1_to_n(5) == [1, 2, 3, 4, 5]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': 'Example if n = 5 then\n**Return:** `[1, 2, 3, 4, 5]`'},
#    {'question': 'even_numbers_1_to_n',
#     'assertion': 'assert even_numbers_1_to_n(11) == [2, 4, 6, 8, 10]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': 'Example if n = 11 then\n**Return:** `[2, 4, 6, 8, 10]`'},
#    {'question': 'square_number',
#     'assertion': 'assert square_number(4) == 16',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': '**Example:** For input `4`, return `16`'},
#    {'question': 'square_number',
#     'assertion': 'assert square_number(0) == 0',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': '**Example:** For input `4`, return `16`'},
#    {'question': 'check_password',
#     'assertion': "assert check_password('python') == 'Access Granted'",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'check_password',
#     'assertion': "assert check_password('PYTHON') == 'Access Denied'",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'check_password',
#     'assertion': "assert check_password('java') == 'Access Denied'",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `'java'` → `'Access Denied'`; Input `'python'` → `'Access Granted'`"},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(4, 9) == 9',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(10, 3) == 10',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'larger_number',
#     'assertion': 'assert larger_number(5, 5) == 5',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': '**Example:** Input `(4, 9)` → `9`  \n**Return:** The larger number.'},
#    {'question': 'even_or_odd',
#     'assertion': "assert even_or_odd(2) == 'Even'",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `4` → `'Even'`"},
#    {'question': 'even_or_odd',
#     'assertion': "assert even_or_odd(3) == 'Odd'",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `4` → `'Even'`"},
#    {'question': 'sum_1_to_n',
#     'assertion': 'assert sum_1_to_n(5) == 15',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': '**Example:** Input `5` → `15`\nbecause 1+2'},
#    {'question': 'sum_1_to_n',
#     'assertion': 'assert sum_1_to_n(10) == 55',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': '**Example:** Input `5` → `15`\nbecause 1+2'},
#    {'question': 'squares_1_to_n',
#     'assertion': 'assert squares_1_to_n(5) == [1, 4, 9, 16, 25]',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': 'if n is 5\n**Return:** `[1, 4, 9, 16, 25]`'},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('banana', 'a') == 3",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('apple', 'p') == 2",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'count_letter',
#     'assertion': "assert count_letter('python', 'z') == 0",
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': "**Example:** Input `('banana', 'a')`\n**Return:** `3`"},
#    {'question': 'average_of_three',
#     'assertion': 'assert round(average_of_three(4, 8, 10), 2) == 7.33',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nTypeError: type NoneType doesn\'t define __round__ method\n',
#     'score': 0,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'},
#    {'question': 'average_of_three',
#     'assertion': 'assert average_of_three(3, 3, 3) == 3',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'},
#    {'question': 'average_of_three',
#     'assertion': 'assert average_of_three(10, 0, 5) == 5',
#     'status': 'failed',
#     'error': 'Traceback (most recent call last):\n  File "/app/src/instantgrade/comparison/comparison_service.py", line 44, in run_assertions\n    exec(compile(code, "<assertion>", "exec"), ns)\n  File "<assertion>", line 1, in <module>\nAssertionError\n',
#     'score': 0,
#     'description': '**Example:** Input `(4, 8, 10)` → `7.3333...`  \n**Return:** The arithmetic mean of the three numbers.'}]},
#  {'student_path': PosixPath('submissions/student_notebook.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='student name', roll='student roll number'\n[grader] Namespace after execution: ['average_of_three', 'check_number', 'check_password', 'count_letter', 'even_numbers_1_to_n', 'even_or_odd', 'larger_number', 'name', 'numbers_1_to_n', 'roll_number', 'square_number', 'squares_1_to_n', 'sum_1_to_n']\n[grader] Final resolved student identity -> name='student name', roll='student roll number'\n[grader] ❌ Fatal: student identity still matches instructor defaults. Skipping assertions.",
#    'docker_stderr': '',
#    'elapsed': 0.64,
#    'student_meta': {'name': 'student name',
#     'roll_number': 'student roll number'}},
#   'results': [{'question': '_identity_check_',
#     'assertion': '[missing student identity]',
#     'status': 'failed',
#     'error': "Student notebook missing personalized name/roll_number. Please define:\n\nname = 'Your Name'\nroll_number = 'Your Roll Number'\n",
#     'score': 0,
#     'description': 'Student did not customize name/roll_number.'}]}]

# %% [markdown]
# # EOF
