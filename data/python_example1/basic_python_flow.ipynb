# %% [markdown]
# # Basic Python Flow

# %%
import sys
from pathlib import Path

# current notebook is inside ./data/python_example1/
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent.parent     # go up two levels to project root

sys.path.append(str(PROJECT_ROOT / "src"))

from instantgrade import Evaluator

# %%
from instantgrade.utils.io_utils import generate_student_notebook

generate_student_notebook(
    instructor_path="./sample_solutions.ipynb",
    output_path="./submissions/student_notebook.ipynb"
)
# Out:
# ✅ Student notebook generated at: submissions/student_notebook.ipynb

# %%
# Method 1: With logging to file (Recommended!)
eval = Evaluator(
    solution_file_path="./sample_solutions.ipynb",
    submission_folder_path="./submissions",
    log_file="./report/evaluation_log.txt"  # Logs saved here!
)
result = eval.run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Method 1: With logging to file (Recommended!)
# ----> 2 eval = Evaluator(
#       3     solution_file_path="./sample_solutions.ipynb",
#       4     submission_folder_path="./submissions",
#       5     log_file="./report/evaluation_log.txt"  # Logs saved here!
#       6 )
#       7 result = eval.run()
#
# TypeError: Evaluator.__init__() got an unexpected keyword argument 'log_file'

# %%
from instantgrade.utils.path_utils import filename_safe_timestamp_format

result.to_html(f"./report/report_{filename_safe_timestamp_format()}.html")
# Out:
# PosixPath('report/report_20251201_164554.html')

# %% [markdown]
# # EOF
