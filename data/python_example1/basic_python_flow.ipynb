# %% [markdown]
# # Basic Python Flow

# %%
import sys
from pathlib import Path

# current notebook is inside ./data/python_example1/
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent.parent     # go up two levels to project root

sys.path.append(str(PROJECT_ROOT / "src"))

from evaluator import Evaluator

# %%
eval = Evaluator("./control_flow_practice_questions.ipynb", "./submissions")
result = eval.run()
# Out:
# [{'student_path': PosixPath('submissions/student_notebook.ipynb'), 'execution': {'namespace': {'name': 'student name', 'roll_number': 'student roll number', 'check_number': <function check_number at 0x112af7b00>, 'numbers_1_to_10': <function numbers_1_to_10 at 0x112af7a60>, 'even_1_to_20': <function even_1_to_20 at 0x112af7920>, 'is_leap_year': <function is_leap_year at 0x112af7ba0>, 'ask_password': <function ask_password at 0x112b3f380>, 'count_vowels': <function count_vowels at 0x112b3f740>, 'sum_1_to_100_loop': <function sum_1_to_100_loop at 0x112b3f600>, 'largest_of_five': <function largest_of_five at 0x112b3f420>, 'mood_response': <function mood_response at 0x112b3f4c0>, '__builtins__': {'__name__': 'builtins', '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed expli
# ...

# %%
from evaluator.utils.path_utils import filename_safe_timestamp_format

result.to_html(f"./report/report_{filename_safe_timestamp_format()}.html")
# Out:
# PosixPath('report/report_20251126_203319.html')

# %%
from evaluator.utils.io_utils import generate_student_notebook


generate_student_notebook(
    instructor_path="/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/python_example1/control_flow_practice_questions.ipynb",
    output_path="/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/python_example1/submissions/control_flow_practice_questions_student_notebook.ipynb"
)
# Out:
# ✅ Student notebook generated at: /Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/python_example1/submissions/control_flow_practice_questions_student_notebook.ipynb

# %% [markdown]
# # EOF
