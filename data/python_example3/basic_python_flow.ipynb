# %% [markdown]
# # Basic Python Flow

# %%
import sys
from pathlib import Path

# current notebook is inside ./data/python_example1/
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent.parent     # go up two levels to project root

sys.path.append(str(PROJECT_ROOT / "src"))

from instantgrade import Evaluator

# %%
from instantgrade.utils.io_utils import generate_student_notebook

generate_student_notebook(
    instructor_path="./sample_solutions.ipynb",
    output_path="./submissions/student_notebook.ipynb"
)
# Out:
# ✅ Student notebook generated at: submissions/student_notebook.ipynb

# %%
from instantgrade.evaluator import Evaluator

eval = Evaluator(
    solution_file_path="./sample_solutions.ipynb",
    submission_folder_path="./submissions",
    use_docker=True,       # or False for local test mode
    log_path="./logs",
    log_level="normal",
)

report = eval.run()
eval.to_html("./reports/evaluation_report.html")
# Out:
# 20:26:27 | INFO     | Starting evaluation pipeline...
# 20:26:27 | INFO     | Loading instructor solution...
# 20:26:27 | INFO     | Loaded 11 questions.
# 20:26:27 | INFO     | Discovered 6 submissions to grade.
# 20:26:27 | INFO     | Starting Docker-based evaluation pipeline...
# 20:26:28 | INFO     | [Docker] Found prebuilt image instantgrade:latest
# 20:26:28 | INFO     | [1/6] Grading: sample_solutions copy.ipynb
# 20:26:28 | INFO     | [Docker] Starting grading for sample_solutions copy.ipynb
# 20:26:28 | INFO     | [sample_solutions copy.ipynb][docker] Traceback (most recent call last):
# 20:26:28 | INFO     | [sample_solutions copy.ipynb][docker]   File "/usr/local/bin/grader.py", line 14, in <module>
# 20:26:28 | INFO     | [sample_solutions copy.ipynb][docker]     from instantgrade.ingestion.solution_ingestion import SolutionIngestion
# 20:26:28 | INFO     | [sample_solutions copy.ipynb][docker] ModuleNotFoundError: No module named 'instantgrade'
# 20:26:28 | WARNING  | [grader] results.json not found in /workspace for sample_solutions copy.ipynb.
# 20:26:28 | INFO     | [2/6] Grading: sample_solutions.ipynb
# 20:26:28 | INFO     | [Docker] Starting grading for sample_solutions.ipynb
# 20:26:28 | INFO     | [sample_solutions.ipynb][docker] Traceback (most recent call last):
# 20:26:28 | INFO     | [sample_solutions.ipynb][docker]   File "/usr/local/bin/grader.py", line 14, in <module>
# 20:26:28 | INFO     | [sample_solutions.ipynb][docker]     from instantgrade.ingestion.solution_ingestion import SolutionIngestion
# 20:26:28 | INFO     | [sample_solutions.ipynb][docker] ModuleNotFoundError: No module named 'instantgrade'
# 20:26:28 | WARNING  | [grader] results.json not found in /workspace for sample_solutions.ipynb.
# 20:26:28 | INFO     | [3/6] Grading: sample_solutions_1.ipynb
# 20:26:28 | INFO     | [Docker] Starting grading for sample_solutions_1.ipynb
# 20:26:28 | INFO     | [sample_solutions_1.ipynb][docker] Traceback (most recent call last):
# 20:26:28 | INFO     | [sample_solutions_1.ipynb][docker]   File "/usr/local/bin/grader.py", line 14, in <module>
# 20:26:28 | INFO     | [sample_solutions_1.ipynb][docker]     from instantgrade.ingestion.solution_ingestion import SolutionIngestion
# 20:26:28 | INFO     | [sample_solutions_1.ipynb][docker] ModuleNotFoundError: No module named 'instantgrade'
# 20:26:28 | WARNING  | [grader] results.json not found in /workspace for sample_solutions_1.ipynb.
# 20:26:28 | INFO     | [4/6] Grading: sample_solutions_2.ipynb
# 20:26:28 | INFO     | [Docker] Starting grading for sample_solutions_2.ipynb
# 20:26:29 | INFO     | [sample_solutions_2.ipynb][docker] Traceback (most recent call last):
# 20:26:29 | INFO     | [sample_solutions_2.ipynb][docker]   File "/usr/local/bin/grader.py", line 14, in <module>
# 20:26:29 | INFO     | [sample_solutions_2.ipynb][docker]     from instantgrade.ingestion.solution_ingestion import SolutionIngestion
# 20:26:29 | INFO     | [sample_solutions_2.ipynb][docker] ModuleNotFoundError: No module named 'instantgrade'
# 20:26:29 | WARNING  | [grader] results.json not found in /workspace for sample_solutions_2.ipynb.
# 20:26:29 | INFO     | [5/6] Grading: student_notebook copy.ipynb
# 20:26:29 | INFO     | [Docker] Starting grading for student_notebook copy.ipynb
# 20:26:29 | INFO     | [student_notebook copy.ipynb][docker] Traceback (most recent call last):
# 20:26:29 | INFO     | [student_notebook copy.ipynb][docker]   File "/usr/local/bin/grader.py", line 14, in <module>
# 20:26:29 | INFO     | [student_notebook copy.ipynb][docker]     from instantgrade.ingestion.solution_ingestion import SolutionIngestion
# 20:26:29 | INFO     | [student_notebook copy.ipynb][docker] ModuleNotFoundError: No module named 'instantgrade'
# 20:26:29 | WARNING  | [grader] results.json not found in /workspace for student_notebook copy.ipynb.
# 20:26:29 | INFO     | [6/6] Grading: student_notebook.ipynb
# 20:26:29 | INFO     | [Docker] Starting grading for student_notebook.ipynb
# 20:26:29 | INFO     | [student_notebook.ipynb][docker] Traceback (most recent call last):
# 20:26:29 | INFO     | [student_notebook.ipynb][docker]   File "/usr/local/bin/grader.py", line 14, in <module>
# 20:26:29 | INFO     | [student_notebook.ipynb][docker]     from instantgrade.ingestion.solution_ingestion import SolutionIngestion
# 20:26:29 | INFO     | [student_notebook.ipynb][docker] ModuleNotFoundError: No module named 'instantgrade'
# 20:26:29 | WARNING  | [grader] results.json not found in /workspace for student_notebook.ipynb.
# 20:26:29 | INFO     | Execution phase completed successfully.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 11
#       1 from instantgrade.evaluator import Evaluator
#       3 eval = Evaluator(
#       4     solution_file_path="./sample_solutions.ipynb",
#       5     submission_folder_path="./submissions",
#    (...)      8     log_level="normal",
#       9 )
# ---> 11 report = eval.run()
#      12 eval.to_html("./reports/evaluation_report.html")
#
# File /Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/instantgrade/evaluator.py:89, in Evaluator.run(self)
#      86 self.logger.info("Execution phase completed successfully.")
#      88 # 4. Build report
# ---> 89 self.report = ReportingService(executed, logger=self.logger)
#      90 self.logger.info("Report generation complete.")
#      92 elapsed = round(time.time() - start_time, 2)
#
# File /Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/instantgrade/reporting/reporting_service.py:22, in ReportingService.__init__(self, executed_results, solution, debug, logger)
#      20 self.solution = solution or {}
#      21 self.df: pd.DataFrame | None = self.dataframe(executed_results)
# ---> 22 if self.logger:
#      23     self.logger.info(f"[Reporting] Processed {len(self.df)} result rows.")
#
# AttributeError: 'ReportingService' object has no attribute 'logger'

# %%
from evaluator.utils.path_utils import filename_safe_timestamp_format

result.to_html(f"./report/report_{filename_safe_timestamp_format()}.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from evaluator.utils.path_utils import filename_safe_timestamp_format
#       3 result.to_html(f"./report/report_{filename_safe_timestamp_format()}.html")
#
# ModuleNotFoundError: No module named 'evaluator'

# %% [markdown]
# # EOF
